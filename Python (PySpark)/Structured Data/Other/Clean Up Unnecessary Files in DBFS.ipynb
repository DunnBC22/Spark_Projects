# %% [markdown]
# ### Function to Remove Individual Files From Databricks File System

# %%
# Function to remove individual files
def remove_list_of_files(files_to_remove):
    for x in files_to_remove:
        dbutils.fs.rm(x)

files = ["/FileStore/tables/Translated_Wikipedia_Biographies___EN_DE.tsv",
         "/FileStore/tables/Translated_Wikipedia_Biographies___EN_ES.tsv", 
         "/FileStore/tables/WikiReady.tsv",]

#remove_list_of_files(files)

# %% [markdown]
# ### Function to Remove Folders From Databricks File System

# %%
# Function to remove folders of files
def remove_list_of_folders(folders_to_remove):
    for x in folders_to_remove:
        dbutils.fs.rm(x)

folders = ["/FileStore/tables/trip_advisors", 
                     "/FileStore/tables/Twitter Sentiment Analysis", 
                     "/FileStore/tables/imdb", 
                     "/FileStore/tables/prepped_imdb_ds", 
                     "/FileStore/tables/NLP-Machine-Translation"]

#remove_list_of_folders(folders)

# %% [markdown]
# ### Notes
# ****
# - I thought I would inlcude a file with the prebuilt functions I use to clean up files and folders within DBFS to keep it tidy!
# ****
